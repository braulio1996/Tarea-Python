# %% [markdown]
# Presentado por: Diego Quisi
#
# # Entornos de soporte al desarrollo de simulaciones: Simpy - Parte 2
#
#
# ## Generacion de graficar de atencion.
#
# En base a la simulacion anterior generar una grafica de los autos atendidos.

# %%
import simpy
import random
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo que tarda en lavarse un vehiculo (minutos)
TIEMPO_LAVADO = 10 
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 3
# Tiempo de simulación
TIEMPO_SIMULACION = 27

# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
tiempo={}

class Lavanderia(object):
    
    def __init__(self, environment, num_maquinas, tiempo_lavado):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        # Variable para el tiempo de lavado
        self.tiempo_lavado = tiempo_lavado
        
    def lavar_vehiculo(self, vehiculo):
        # Este metodo representa el proceso de lavado del vehículo.
        # Se ingresa el vehículo y se lava
        
        # Simulamos el tiempo que tarda en lavarse el vehiculo
        # Es importante notar que la instruccion "yield" es distinta de "sleep"
        # ya que esta ultima bloquea el hilo de ejecucion durante 't' unidades de tiempo,
        # mientras que 'yield' no bloquea el hilo de ejecucion, solo lo suspende mientras
        # el evento de 'lavado' se realice
        yield self.env.timeout(random.randint(TIEMPO_LAVADO-5, TIEMPO_LAVADO+5))
        
        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        
    
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega vehiculo: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with lavanderia.maquinas.request() as maquina:
        # Ocupamos la maquina de lavado
        yield maquina
        # Indicamos que vehiculo entra a la lavanderia
        print('Entra vehiculo a lavarse: %s a la hora %.2f.' % (nombre, env.now))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f.' % (nombre, env.now))

       
        tiempo[nombre]=env.now
        
    
def ejecutar_simulacion(env, num_maquinas, tiempo_lavado, intervalo):
    lavanderia=Lavanderia(env, num_maquinas, tiempo_lavado)
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(5):
        env.process(llegada_vehiculo(env, 'Vehiculo-%d'%(i+1),lavanderia))
    
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        env.process(llegada_vehiculo(env,'Vehiculo-%d'%(i+1),lavanderia))

print('Lavanderia UPS')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS, TIEMPO_LAVADO, INTERVALO_LLEGADA))

# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)


print("Diccionario timepo :")
print(tiempo)
# Out:
# Lavanderia UPS
# Llega vehiculo: Vehiculo-1 a la hora 0.00.
# Llega vehiculo: Vehiculo-2 a la hora 0.00.
# Llega vehiculo: Vehiculo-3 a la hora 0.00.
# Llega vehiculo: Vehiculo-4 a la hora 0.00.
# Llega vehiculo: Vehiculo-5 a la hora 0.00.
# Entra vehiculo a lavarse: Vehiculo-1 a la hora 0.00.
# Entra vehiculo a lavarse: Vehiculo-2 a la hora 0.00.
# Entra vehiculo a lavarse: Vehiculo-3 a la hora 0.00.
# Removido  {60%} suciedad vehiculo => Vehiculo-1
# Removido  {79%} suciedad vehiculo => Vehiculo-2
# Vehiculo [Vehiculo-1] lavado a las 5.00.
# Vehiculo [Vehiculo-2] lavado a las 5.00.
# Entra vehiculo a lavarse: Vehiculo-4 a la hora 5.00.
# Entra vehiculo a lavarse: Vehiculo-5 a la hora 5.00.
# Llega vehiculo: Vehiculo-6 a la hora 6.00.
# Llega vehiculo: Vehiculo-7 a la hora 7.00.
# Llega vehiculo: Vehiculo-8 a la hora 7.00.
# Removido  {57%} suciedad vehiculo => Vehiculo-4
# Llega vehiculo: Vehiculo-9 a la hora 10.00.
# Vehiculo [Vehiculo-4] lavado a las 10.00.
# Entra vehiculo a lavarse: Vehiculo-6 a la hora 10.00.
# Removido  {44%} suciedad vehiculo => Vehiculo-5
# Vehiculo [Vehiculo-5] lavado a las 12.00.
# Entra vehiculo a lavarse: Vehiculo-7 a la hora 12.00.
# Removido  {63%} suciedad vehiculo => Vehiculo-3
# Llega vehiculo: Vehiculo-10 a la hora 15.00.
# Vehiculo [Vehiculo-3] lavado a las 15.00.
# Entra vehiculo a lavarse: Vehiculo-8 a la hora 15.00.
# Removido  {75%} suciedad vehiculo => Vehiculo-6
# Llega vehiculo: Vehiculo-11 a la hora 19.00.
# Vehiculo [Vehiculo-6] lavado a las 19.00.
# Llega vehiculo: Vehiculo-12 a la hora 19.00.
# Llega vehiculo: Vehiculo-13 a la hora 19.00.
# Entra vehiculo a lavarse: Vehiculo-9 a la hora 19.00.
# Removido  {69%} suciedad vehiculo => Vehiculo-7
# Llega vehiculo: Vehiculo-14 a la hora 24.00.
# Vehiculo [Vehiculo-7] lavado a las 24.00.
# Entra vehiculo a lavarse: Vehiculo-10 a la hora 24.00.
# Llega vehiculo: Vehiculo-15 a la hora 26.00.
# Diccionario timepo :
# {'Vehiculo-1': 5, 'Vehiculo-2': 5, 'Vehiculo-4': 10, 'Vehiculo-5': 12, 'Vehiculo-3': 15, 'Vehiculo-6': 19, 'Vehiculo-7': 24}

# %%
# Generamos la grafica
datos=sorted(tiempo.items()) # Ordenamos los datos
x, y =zip(*datos) # Obtener x(tiempo - clave) y el y(Numero de vehiculos atendidos - valor)
pp.plot(x,y,linewidth=2,color='red') #Dibujamos las lineas
pp.scatter(x,y,color='blue') # Dibujamos los puntos (x,y)
pp.title("Vehiculos Atenndidos X Tiempo")
pp.grid(True) #Generamos una cuadricula
pp.show() #Mostramos el grafico

# %% [markdown]
# ## Paremetrizando la simulacion
#
# * Considerar 3 tipos de vehículos con 3 diferentes tiempos de lavado:
#     * Bus: 20 minutos
#     * Automóvil: 7 minutos
#     * Furgoneta: 12 minutos
# * Considere que a partir de la entrada del vehículo para ser lavado, deberán tomarse en cuenta los siguientes tiempos correspondientes al proceso de traslado desde la recepción a la máquina de lavado:
#     * Bus: 4 minutos
#     * Automóvil: 1 minuto
#     * Furgoneta: 2 minutos
# * Realice una gráfica de la simulación con 3 máquinas de lavado

# %%
import simpy
import random
import matplotlib.pyplot as pp

# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57 
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo que tarda en trasladarse un vehiculo (minutos)
TRASLADO_BUS = 4
TRASLADO_AUTOMOVIL= 1
TRASLADO_FURGONETA= 2
# Tiempo que tarda en lavarse un vehiculo (minutos)
TIEMPO_BUS = 20
TIEMPO_AUTOMOVIL= 7
TIEMPO_FURGONETA= 12
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 10
# Tiempo de simulación
TIEMPO_SIMULACION = 100

# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
tiempo={}

class Lavanderia(object):
    
    def __init__(self, environment, num_maquinas,tiempo_bus,tiempo_automovil,
                 tiempo_furgoneta,traslado_bus,traslado_automovil,traslado_furgoneta):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        # Variable para el tiempo de lavado
        self.tiempo_bus = tiempo_bus
        self.tiempo_automovil = tiempo_automovil
        self.tiempo_furgoneta = tiempo_furgoneta
        self.traslado_bus = traslado_bus
        self.traslado_automovil = traslado_automovil
        self.traslado_furgoneta = traslado_furgoneta
        
    def lavar_vehiculo(self, vehiculo):
        automotor=vehiculo.split('-')
        if(automotor[0] == 'Bus'):
            yield self.env.timeout(TIEMPO_BUS)
        if(automotor[0] == 'Automovil'):
            yield self.env.timeout(TIEMPO_AUTOMOVIL)
        if(automotor[0] == 'Furgoneta'):
            yield self.env.timeout(TIEMPO_FURGONETA)
        #Solo agregamos al diccionario al momento que termina de lavar el vehiculo.
        k=automotor[0]
        if k in tiempo:
            tiempo[k]=tiempo[k]+1
        else:
            tiempo[k]=1
            
        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        print('Removido  {%d%%} suciedad vehiculo => %s ' %(random.randint(30,90), vehiculo))
        
    def trasladar_vehiculo(self, vehiculo):
        automotor=vehiculo.split('-')
        if(automotor[0] == 'Bus'):
            yield self.env.timeout(TRASLADO_BUS)
        if(automotor[0] == 'Automovil'):
            yield self.env.timeout(TRASLADO_AUTOMOVIL)
        if(automotor[0] == 'Furgoneta'):
            yield self.env.timeout(TRASLADO_FURGONETA)
       
    
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega vehiculo: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with lavanderia.maquinas.request() as maquina:
        # Ocupamos la maquina de lavado
        yield maquina
        #Indicamos que el vehiculo se esta trasladando para ser lavado
        print('Se traslada vehiculo: %s a la hora %.2f.' % (nombre,env.now))
        #Procesamos el traslado del vehiculo
        yield env.process(lavanderia.trasladar_vehiculo(nombre))
        # Indicamos que vehiculo entra a la lavanderia
        print('Entra vehiculo a lavarse: %s a la hora %.2f.' % (nombre, env.now))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f.' % (nombre, env.now))  
        
def ejecutar_simulacion(env, num_maquinas, tiempo_bus,tiempo_automovil,
                        tiempo_furgoneta,traslado_bus,traslado_automovil,
                        traslado_furgoneta, intervalo):
    lavanderia=Lavanderia(env, num_maquinas, tiempo_bus,tiempo_automovil,
                          tiempo_furgoneta,traslado_bus,traslado_automovil,
                          traslado_furgoneta)
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(2):
        env.process(llegada_vehiculo(env, 'Bus-%d'%(i+1),lavanderia))
        env.process(llegada_vehiculo(env, 'Automovil-%d'%(i+1),lavanderia))
        env.process(llegada_vehiculo(env, 'Furgoneta-%d'%(i+1),lavanderia))
        
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        rnd = random.randint(1,100)
        if rnd <= 20: # Bus 20%, Furgoneta 30% y Automovil 50%
            env.process(llegada_vehiculo(env,'Bus-%d'%(i+1),lavanderia))
        elif rnd <= 50:
            env.process(llegada_vehiculo(env,'Furgoneta-%d'%(i+1),lavanderia))
        else:
            env.process(llegada_vehiculo(env,'Automovil-%d'%(i+1),lavanderia))

print('Lavanderia UPS')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS, TIEMPO_BUS,TIEMPO_AUTOMOVIL,
                                TIEMPO_FURGONETA,TRASLADO_BUS,TRASLADO_AUTOMOVIL,
                                TRASLADO_FURGONETA, INTERVALO_LLEGADA))
# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)

# Generamos la grafica
datos=sorted(tiempo.items())
x, y =zip(*datos)
pp.plot(x,y,linewidth=2,color='red')
pp.scatter(x,y,color='blue')
pp.grid(True)
pp.show()
# Out:
# Lavanderia UPS
# Llega vehiculo: Bus-1 a la hora 0.00.
# Llega vehiculo: Automovil-1 a la hora 0.00.
# Llega vehiculo: Furgoneta-1 a la hora 0.00.
# Llega vehiculo: Bus-2 a la hora 0.00.
# Llega vehiculo: Automovil-2 a la hora 0.00.
# Llega vehiculo: Furgoneta-2 a la hora 0.00.
# Se traslada vehiculo: Bus-1 a la hora 0.00.
# Se traslada vehiculo: Automovil-1 a la hora 0.00.
# Se traslada vehiculo: Furgoneta-1 a la hora 0.00.
# Entra vehiculo a lavarse: Automovil-1 a la hora 1.00.
# Entra vehiculo a lavarse: Furgoneta-1 a la hora 2.00.
# Entra vehiculo a lavarse: Bus-1 a la hora 4.00.
# Llega vehiculo: Automovil-3 a la hora 8.00.
# Removido  {68%} suciedad vehiculo => Automovil-1
# Vehiculo [Automovil-1] lavado a las 8.00.
# Se traslada vehiculo: Bus-2 a la hora 8.00.
# Entra vehiculo a lavarse: Bus-2 a la hora 12.00.
# Removido  {37%} suciedad vehiculo => Furgoneta-1
# Vehiculo [Furgoneta-1] lavado a las 14.00.
# Se traslada vehiculo: Automovil-2 a la hora 14.00.
# Entra vehiculo a lavarse: Automovil-2 a la hora 15.00.
# Llega vehiculo: Furgoneta-4 a la hora 19.00.
# Removido  {58%} suciedad vehiculo => Automovil-2
# Vehiculo [Automovil-2] lavado a las 22.00.
# Se traslada vehiculo: Furgoneta-2 a la hora 22.00.
# Removido  {66%} suciedad vehiculo => Bus-1
# Vehiculo [Bus-1] lavado a las 24.00.
# Entra vehiculo a lavarse: Furgoneta-2 a la hora 24.00.
# Se traslada vehiculo: Automovil-3 a la hora 24.00.
# Entra vehiculo a lavarse: Automovil-3 a la hora 25.00.
# Llega vehiculo: Furgoneta-5 a la hora 31.00.
# Removido  {48%} suciedad vehiculo => Bus-2
# Removido  {84%} suciedad vehiculo => Automovil-3
# Vehiculo [Bus-2] lavado a las 32.00.
# Vehiculo [Automovil-3] lavado a las 32.00.
# Se traslada vehiculo: Furgoneta-4 a la hora 32.00.
# Se traslada vehiculo: Furgoneta-5 a la hora 32.00.
# Entra vehiculo a lavarse: Furgoneta-4 a la hora 34.00.
# Entra vehiculo a lavarse: Furgoneta-5 a la hora 34.00.
# Removido  {67%} suciedad vehiculo => Furgoneta-2
# Vehiculo [Furgoneta-2] lavado a las 36.00.
# Llega vehiculo: Furgoneta-6 a la hora 43.00.
# Se traslada vehiculo: Furgoneta-6 a la hora 43.00.
# Entra vehiculo a lavarse: Furgoneta-6 a la hora 45.00.
# Removido  {37%} suciedad vehiculo => Furgoneta-4
# Removido  {30%} suciedad vehiculo => Furgoneta-5
# Vehiculo [Furgoneta-4] lavado a las 46.00.
# Vehiculo [Furgoneta-5] lavado a las 46.00.
# Llega vehiculo: Automovil-7 a la hora 50.00.
# Se traslada vehiculo: Automovil-7 a la hora 50.00.
# Entra vehiculo a lavarse: Automovil-7 a la hora 51.00.
# Removido  {48%} suciedad vehiculo => Furgoneta-6
# Vehiculo [Furgoneta-6] lavado a las 57.00.
# Llega vehiculo: Bus-8 a la hora 58.00.
# Removido  {40%} suciedad vehiculo => Automovil-7
# Se traslada vehiculo: Bus-8 a la hora 58.00.
# Vehiculo [Automovil-7] lavado a las 58.00.
# Entra vehiculo a lavarse: Bus-8 a la hora 62.00.
# Llega vehiculo: Bus-9 a la hora 66.00.
# Se traslada vehiculo: Bus-9 a la hora 66.00.
# Entra vehiculo a lavarse: Bus-9 a la hora 70.00.
# Llega vehiculo: Furgoneta-10 a la hora 77.00.
# Se traslada vehiculo: Furgoneta-10 a la hora 77.00.
# Entra vehiculo a lavarse: Furgoneta-10 a la hora 79.00.
# Removido  {62%} suciedad vehiculo => Bus-8
# Vehiculo [Bus-8] lavado a las 82.00.
# Llega vehiculo: Automovil-11 a la hora 89.00.
# Se traslada vehiculo: Automovil-11 a la hora 89.00.
# Removido  {71%} suciedad vehiculo => Bus-9
# Vehiculo [Bus-9] lavado a las 90.00.
# Entra vehiculo a lavarse: Automovil-11 a la hora 90.00.
# Removido  {48%} suciedad vehiculo => Furgoneta-10
# Vehiculo [Furgoneta-10] lavado a las 91.00.
# Removido  {88%} suciedad vehiculo => Automovil-11
# Vehiculo [Automovil-11] lavado a las 97.00.

# %% [markdown]
# ## Práctica  Sympy 2
#
# En base a la simulacion, generar una simulacion lo mas apegado a la realidad del Covid-19, para ello obtener informacion del numero de consultorios y camas disponibles en un hospital del Ecuador. Parametrizar la simulacion para ingresar el numero de pacientes, el numero de consultorios y el numero de camas y algun otro parametro que considere oportuno.
#
# Finalmente generar las siguientes metricas :
# - Tiempo de espera promedio para cada sala.
# - Tiempo promedio total que requiere un paciente para ser atendido desde cero.
# - Cuántos pacientes se atendieron.
# - Cuántos pacientes se quedaron sin atender y fallecieron.

# %% [markdown]
# - Investigar el proceso de atencion de un paciente diagnosticado con COVID-19, ademas de tiempos de atencion, recursos necesarios y tipos de pacientes.
#
# - Investigar en cada una de las provincias asignadas el numero de hospitales, camas, respiradores y personal medico, limpieza y enfermeria.
#   - Cotopaxi	 567
#     1. Ministerio de Salud Pública	 290
#     2. Ministerio de Defensa Nacional	 11
#     3. Instituto Ecuatoriano de Seguridad Social	 95
#     4. Fiscomisionales	 35
#     5. vados con fines de lucro	 136
#
# - Finalmente el costo de atender a un paciente con COVID-19 y medicamentos.
#     1. consto prueba intitucion privada 200
#     2. ministerio de salud publica gratis
#
#
#
#
#
#
#   -otopaxi 59 casos
#   -dia =17

# %%
import simpy
import random
import matplotlib.pyplot as plt

# %matplotlib inline

# maximo de pacientes por dia 
MAX_PACIENTES = 200
# Total de consultorios
NUM_CONSULTORIOS = 4
# Tiempo que tarda en atenderse un paciente (minutos)
TIEMPO_ATENCION = 17
# Intervalo de tiempo en que llegan pacientes(minutos)
INTERVALO_LLEGADA = 3
# Tiempo de simulación
TIEMPO_SIMULACION = 200
#Numero de camas
NUM_CAMAS=43;


tiempo={}
Pllegan={}
Patendidos={}
Pno={}

class Hospital(object):
    
    def __init__(self, environment, num_consultorios, tiempo_atencion, camas):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa los consultorios
        self.consultorios = simpy.Resource(environment, num_consultorios)
        
        self.camas = simpy.Resource(environment, camas)
        # Variable para el tiempo de atencion 
        self.tiempo_atencion = tiempo_atencion
        
    def atencion(self, paciente):
        yield self.env.timeout(random.randint(TIEMPO_ATENCION-2, TIEMPO_ATENCION+2))   
        print(chr(27)+"[0;30m"+paciente,' Atendido')
        
    def zona_aislamiento(self, paciente):
        t=random.randint(5, 20)
        rnd = random.randint(1,100)
        #8% de probabilidad de fallecer
        #92% de probabilidad de cura 
        if rnd <= 92:
            yield self.env.timeout(t)
            print(chr(27)+"[0;33m"+'El ',paciente, 'Termina la Hospitalizacion en', t ,' Dias')
        else:
            yield self.env.timeout(t)
            print(chr(27)+"[1;30m"+'El ', paciente, 'Fallece a', t ,' Dias de Hospitalizacion')
        
        tiempo[paciente]=t
        
    
def llegada_paciente(env, nombre, hospital):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el paciente con el nombre pasado como parametro
    print(chr(27)+"[0;30m"+'Llega paciente: %s a la hora %.2f.' % (nombre, (env.now+420)/60))
    Pllegan[nombre]=((env.now+420)/60)
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # el consultorio del Hospital
    with hospital.consultorios.request() as consultorio:
        # Ocupamos la maquina de lavado
        yield consultorio
        # Indicamos que el paciente entra al consultorio
        print(chr(27)+"[0;30m"+'Entra paciente a atenderce: %s a la hora %.2f.' % (nombre, (env.now+420)/60))
        
        # se realiza el test de covid_19
        
        rnd = random.randint(1,100)
        if rnd <= 60: # sanos 60% infectados 40%
            yield env.process(hospital.atencion(nombre))
            print(chr(27)+"[0;32m"+'Paciente Sano [%s] Atendido a las %.2f.' % (nombre, (env.now+420)/60),"Casa")
            tiempo[nombre]=((env.now+420)/60)
            
        else:
            yield env.process(hospital.atencion(nombre))
            print(chr(27)+"[0;31m"+'Paciente Infectado [%s] Atendido a las %.2f.' % (nombre, (env.now+420)/60),"Internado")
            with hospital.camas.request() as cama:
                # Ocupamos el consultorio
                yield cama
                # Indicamos que paciente entra al consultorio
                print('se le asigna a una cama: %s a la hora %.2f.' % (nombre, (env.now+420)/60))
                yield env.process(hospital.zona_aislamiento(nombre))
            
            
        
        
    
def ejecutar_simulacion(env, num_consultorios, tiempo_atencion, intervalo,camas):
    hospital=Hospital(env, num_consultorios, tiempo_atencion, camas)
    # Creamos 5 llegadas de pacientes iniciales
    for i in range(5):
        env.process(llegada_paciente(env, 'Paciente-%d'%(i+1),hospital))
    
    # Ejecutamos la simulacion
    while True:
        yield env.timeout(random.randint(intervalo-3, intervalo+3))
        i+=1
        # Mientras se atienden los pacientes generamos mas pacientes
        env.process(llegada_paciente(env,'Paciente-%d'%(i+1),hospital))

print('Hospital')

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_CONSULTORIOS, TIEMPO_ATENCION, INTERVALO_LLEGADA, NUM_CAMAS))

# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)
print("\n")
print(chr(27)+"[0;34m"+"Numero de pacientes :",len(Pllegan))
print(chr(27)+"[0;34m"+"Numero de pacientes Atendidos:",len(tiempo))
print(chr(27)+"[0;34m"+"Numero de pacientes se quedaron sin atender y fallecieron:",len(Pllegan)-len(tiempo))
# Out:
# Hospital
# Llega paciente: Paciente-1 a la hora 7.00.
# Llega paciente: Paciente-2 a la hora 7.00.
# Llega paciente: Paciente-3 a la hora 7.00.
# Llega paciente: Paciente-4 a la hora 7.00.
# Llega paciente: Paciente-5 a la hora 7.00.
# Entra paciente a atenderce: Paciente-1 a la hora 7.00.
# Entra paciente a atenderce: Paciente-2 a la hora 7.00.
# Entra paciente a atenderce: Paciente-3 a la hora 7.00.
# Entra paciente a atenderce: Paciente-4 a la hora 7.00.
# Llega paciente: Paciente-6 a la hora 7.07.
# Llega paciente: Paciente-7 a la hora 7.17.
# Llega paciente: Paciente-8 a la hora 7.22.
# Llega paciente: Paciente-9 a la hora 7.22.
# Paciente-4  Atendido
# Paciente Infectado [Paciente-4] Atendido a las 7.25. Internado
# se le asigna a una cama: Paciente-4 a la hora 7.25.
# Paciente-3  Atendido
# Llega paciente: Paciente-10 a la hora 7.27.
# Paciente Infectado [Paciente-3] Atendido a las 7.27. Internado
# se le asigna a una cama: Paciente-3 a la hora 7.27.
# Paciente-2  Atendido
# Paciente Sano [Paciente-2] Atendido a las 7.28. Casa
# Entra paciente a atenderce: Paciente-5 a la hora 7.28.
# Paciente-1  Atendido
# Paciente Sano [Paciente-1] Atendido a las 7.30. Casa
# Entra paciente a atenderce: Paciente-6 a la hora 7.30.
# Llega paciente: Paciente-11 a la hora 7.37.
# El  Paciente-3 Fallece a 7  Dias de Hospitalizacion
# Entra paciente a atenderce: Paciente-7 a la hora 7.38.
# Llega paciente: Paciente-12 a la hora 7.40.
# El  Paciente-4 Termina la Hospitalizacion en 10  Dias
# Entra paciente a atenderce: Paciente-8 a la hora 7.42.
# Llega paciente: Paciente-13 a la hora 7.43.
# Llega paciente: Paciente-14 a la hora 7.45.
# Llega paciente: Paciente-15 a la hora 7.48.
# Llega paciente: Paciente-16 a la hora 7.50.
# Paciente-5  Atendido
# Paciente Sano [Paciente-5] Atendido a las 7.55. Casa
# Entra paciente a atenderce: Paciente-9 a la hora 7.55.
# Paciente-6  Atendido
# Llega paciente: Paciente-17 a la hora 7.60.
# Paciente Infectado [Paciente-6] Atendido a las 7.60. Internado
# se le asigna a una cama: Paciente-6 a la hora 7.60.
# Paciente-7  Atendido
# Llega paciente: Paciente-18 a la hora 7.65.
# Paciente Sano [Paciente-7] Atendido a las 7.65. Casa
# Entra paciente a atenderce: Paciente-10 a la hora 7.65.
# Llega paciente: Paciente-19 a la hora 7.68.
# El  Paciente-6 Termina la Hospitalizacion en 6  Dias
# Llega paciente: Paciente-20 a la hora 7.70.
# Llega paciente: Paciente-21 a la hora 7.70.
# Entra paciente a atenderce: Paciente-11 a la hora 7.70.
# Paciente-8  Atendido
# Llega paciente: Paciente-22 a la hora 7.72.
# Paciente Infectado [Paciente-8] Atendido a las 7.72. Internado
# Llega paciente: Paciente-23 a la hora 7.72.
# se le asigna a una cama: Paciente-8 a la hora 7.72.
# Llega paciente: Paciente-24 a la hora 7.72.
# Llega paciente: Paciente-25 a la hora 7.72.
# Llega paciente: Paciente-26 a la hora 7.78.
# Paciente-9  Atendido
# Llega paciente: Paciente-27 a la hora 7.87.
# Paciente Sano [Paciente-9] Atendido a las 7.87. Casa
# Entra paciente a atenderce: Paciente-12 a la hora 7.87.
# Paciente-10  Atendido
# Paciente-11  Atendido
# El  Paciente-8 Termina la Hospitalizacion en 15  Dias
# Llega paciente: Paciente-28 a la hora 7.97.
# Paciente Sano [Paciente-10] Atendido a las 7.97. Casa
# Paciente Sano [Paciente-11] Atendido a las 7.97. Casa
# Entra paciente a atenderce: Paciente-13 a la hora 7.97.
# Entra paciente a atenderce: Paciente-14 a la hora 7.97.
# Entra paciente a atenderce: Paciente-15 a la hora 7.97.
# Llega paciente: Paciente-29 a la hora 8.07.
# Llega paciente: Paciente-30 a la hora 8.15.
# Paciente-12  Atendido
# Paciente Sano [Paciente-12] Atendido a las 8.18. Casa
# Entra paciente a atenderce: Paciente-16 a la hora 8.18.
# Llega paciente: Paciente-31 a la hora 8.22.
# Paciente-15  Atendido
# Llega paciente: Paciente-32 a la hora 8.23.
# Paciente Sano [Paciente-15] Atendido a las 8.23. Casa
# Entra paciente a atenderce: Paciente-17 a la hora 8.23.
# Paciente-14  Atendido
# Llega paciente: Paciente-33 a la hora 8.25.
# Paciente Sano [Paciente-14] Atendido a las 8.25. Casa
# Entra paciente a atenderce: Paciente-18 a la hora 8.25.
# Paciente-13  Atendido
# Paciente Sano [Paciente-13] Atendido a las 8.28. Casa
# Entra paciente a atenderce: Paciente-19 a la hora 8.28.
# Llega paciente: Paciente-34 a la hora 8.32.
# Llega paciente: Paciente-35 a la hora 8.37.
# Llega paciente: Paciente-36 a la hora 8.40.
# Llega paciente: Paciente-37 a la hora 8.42.
# Paciente-16  Atendido
# Paciente Infectado [Paciente-16] Atendido a las 8.43. Internado
# se le asigna a una cama: Paciente-16 a la hora 8.43.
# Llega paciente: Paciente-38 a la hora 8.45.
# Llega paciente: Paciente-39 a la hora 8.47.
# Llega paciente: Paciente-40 a la hora 8.47.
# Llega paciente: Paciente-41 a la hora 8.47.
# Paciente-17  Atendido
# Paciente Sano [Paciente-17] Atendido a las 8.50. Casa
# Entra paciente a atenderce: Paciente-20 a la hora 8.50.
# Paciente-18  Atendido
# Paciente Sano [Paciente-18] Atendido a las 8.52. Casa
# Entra paciente a atenderce: Paciente-21 a la hora 8.52.
# Paciente-19  Atendido
# Paciente Infectado [Paciente-19] Atendido a las 8.53. Internado
# se le asigna a una cama: Paciente-19 a la hora 8.53.
# El  Paciente-16 Termina la Hospitalizacion en 8  Dias
# Llega paciente: Paciente-42 a la hora 8.57.
# Entra paciente a atenderce: Paciente-22 a la hora 8.57.
# Llega paciente: Paciente-43 a la hora 8.60.
# Llega paciente: Paciente-44 a la hora 8.63.
# El  Paciente-19 Termina la Hospitalizacion en 7  Dias
# Entra paciente a atenderce: Paciente-23 a la hora 8.65.
# Llega paciente: Paciente-45 a la hora 8.72.
# Llega paciente: Paciente-46 a la hora 8.73.
# Llega paciente: Paciente-47 a la hora 8.73.
# Paciente-20  Atendido
# Paciente Sano [Paciente-20] Atendido a las 8.77. Casa
# Entra paciente a atenderce: Paciente-24 a la hora 8.77.
# Paciente-21  Atendido
# Paciente Infectado [Paciente-21] Atendido a las 8.80. Internado
# se le asigna a una cama: Paciente-21 a la hora 8.80.
# Llega paciente: Paciente-48 a la hora 8.82.
# Paciente-22  Atendido
# Paciente Infectado [Paciente-22] Atendido a las 8.85. Internado
# se le asigna a una cama: Paciente-22 a la hora 8.85.
# Llega paciente: Paciente-49 a la hora 8.88.
# Llega paciente: Paciente-50 a la hora 8.92.
# Paciente-23  Atendido
# Paciente Sano [Paciente-23] Atendido a las 8.93. Casa
# Entra paciente a atenderce: Paciente-25 a la hora 8.93.
# El  Paciente-21 Fallece a 10  Dias de Hospitalizacion
# Entra paciente a atenderce: Paciente-26 a la hora 8.97.
# Llega paciente: Paciente-51 a la hora 9.00.
# Paciente-24  Atendido
# Paciente Sano [Paciente-24] Atendido a las 9.02. Casa
# Entra paciente a atenderce: Paciente-27 a la hora 9.02.
# Llega paciente: Paciente-52 a la hora 9.05.
# El  Paciente-22 Termina la Hospitalizacion en 16  Dias
# Entra paciente a atenderce: Paciente-28 a la hora 9.12.
# Llega paciente: Paciente-53 a la hora 9.15.
# Paciente-25  Atendido
# Llega paciente: Paciente-54 a la hora 9.18.
# Paciente Infectado [Paciente-25] Atendido a las 9.18. Internado
# se le asigna a una cama: Paciente-25 a la hora 9.18.
# Llega paciente: Paciente-55 a la hora 9.22.
# Llega paciente: Paciente-56 a la hora 9.23.
# Paciente-26  Atendido
# Paciente-27  Atendido
# Paciente Infectado [Paciente-26] Atendido a las 9.28. Internado
# Paciente Sano [Paciente-27] Atendido a las 9.28. Casa
# se le asigna a una cama: Paciente-26 a la hora 9.28.
# Entra paciente a atenderce: Paciente-29 a la hora 9.28.
# Llega paciente: Paciente-57 a la hora 9.30.
# Llega paciente: Paciente-58 a la hora 9.32.
# Llega paciente: Paciente-59 a la hora 9.32.
# El  Paciente-25 Termina la Hospitalizacion en 9  Dias
# Entra paciente a atenderce: Paciente-30 a la hora 9.33.
# Paciente-28  Atendido
# Paciente Sano [Paciente-28] Atendido a las 9.37. Casa
# Entra paciente a atenderce: Paciente-31 a la hora 9.37.
# Llega paciente: Paciente-60 a la hora 9.38.
# Llega paciente: Paciente-61 a la hora 9.45.
# Llega paciente: Paciente-62 a la hora 9.45.
# El  Paciente-26 Termina la Hospitalizacion en 11  Dias
# Entra paciente a atenderce: Paciente-32 a la hora 9.47.
# Llega paciente: Paciente-63 a la hora 9.50.
# Paciente-29  Atendido
# Paciente Sano [Paciente-29] Atendido a las 9.53. Casa
# Entra paciente a atenderce: Paciente-33 a la hora 9.53.
# Llega paciente: Paciente-64 a la hora 9.58.
# Llega paciente: Paciente-65 a la hora 9.63.
# Llega paciente: Paciente-66 a la hora 9.63.
# Paciente-30  Atendido
# Paciente Infectado [Paciente-30] Atendido a las 9.65. Internado
# se le asigna a una cama: Paciente-30 a la hora 9.65.
# Paciente-31  Atendido
# Paciente Sano [Paciente-31] Atendido a las 9.67. Casa
# Entra paciente a atenderce: Paciente-34 a la hora 9.67.
# Paciente-32  Atendido
# Llega paciente: Paciente-67 a la hora 9.73.
# Paciente Infectado [Paciente-32] Atendido a las 9.73. Internado
# se le asigna a una cama: Paciente-32 a la hora 9.73.
# Paciente-33  Atendido
# Llega paciente: Paciente-68 a la hora 9.83.
# Paciente Sano [Paciente-33] Atendido a las 9.83. Casa
# Entra paciente a atenderce: Paciente-35 a la hora 9.83.
# Llega paciente: Paciente-69 a la hora 9.90.
# Llega paciente: Paciente-70 a la hora 9.92.
# Llega paciente: Paciente-71 a la hora 9.92.
# El  Paciente-32 Termina la Hospitalizacion en 13  Dias
# Entra paciente a atenderce: Paciente-36 a la hora 9.95.
# El  Paciente-30 Termina la Hospitalizacion en 20  Dias
# Paciente-34  Atendido
# Paciente Sano [Paciente-34] Atendido a las 9.98. Casa
# Entra paciente a atenderce: Paciente-37 a la hora 9.98.
# Entra paciente a atenderce: Paciente-38 a la hora 9.98.
# Llega paciente: Paciente-72 a la hora 10.00.
# Llega paciente: Paciente-73 a la hora 10.03.
# Paciente-35  Atendido
# Llega paciente: Paciente-74 a la hora 10.13.
# Paciente Infectado [Paciente-35] Atendido a las 10.13. Internado
# se le asigna a una cama: Paciente-35 a la hora 10.13.
# Llega paciente: Paciente-75 a la hora 10.20.
# Paciente-36  Atendido
# El  Paciente-35 Termina la Hospitalizacion en 7  Dias
# Paciente Infectado [Paciente-36] Atendido a las 10.25. Internado
# se le asigna a una cama: Paciente-36 a la hora 10.25.
# Entra paciente a atenderce: Paciente-39 a la hora 10.25.
# Paciente-37  Atendido
# Llega paciente: Paciente-76 a la hora 10.28.
# Paciente Sano [Paciente-37] Atendido a las 10.28. Casa
# Entra paciente a atenderce: Paciente-40 a la hora 10.28.
# Paciente-38  Atendido
# Paciente Sano [Paciente-38] Atendido a las 10.30. Casa
# Entra paciente a atenderce: Paciente-41 a la hora 10.30.
#
#
# Numero de pacientes : 76
# Numero de pacientes Atendidos: 37
# Numero de pacientes se quedaron sin atender y fallecieron: 39

# %%
datos=sorted(tiempo.items())
datos2=sorted(Pllegan.items())
x, y =zip(*datos)
x2, y2 =zip(*datos2)
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111,  axisbelow=True)


ax.plot(x,y,linewidth=2,color='red')
ax.scatter(x,y,color='b',label='Numero de pacientes Atendidos')

ax.set_xlabel('Pacientes')
ax.set_ylabel('Tiempo en horas')
legend = ax.legend()
ax.grid(True)

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111,  axisbelow=True)


ax.plot(x2,y2,linewidth=2,color='red')
ax.scatter(x2,y2,color='g',label='Numero de pacientes ')


ax.set_xlabel('Pacientes')
ax.set_ylabel('Tiempo en horas')
legend = ax.legend()
ax.grid(True)

# %% [markdown]
# ## Referencias
# [1] Matloff, N. (2008). Introduction to Discrete-Event Simulation and the SimPy Language.
#
# [2] Team Simpy (2017). SimPy Documentation, Release 3.0.10, 2017. URL: https://media.readthedocs.org/pdf/simpy/latest/simpy.pdf
